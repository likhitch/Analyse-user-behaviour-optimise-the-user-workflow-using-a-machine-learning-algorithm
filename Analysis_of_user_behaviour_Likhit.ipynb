# %%
pip install markovclick
# Out:
# Collecting markovclick
#   Downloading https://files.pythonhosted.org/packages/4a/09/d02be913dad4b9aab33f08b82db61dcf51162f98f8487c79b7cc4f09fd79/markovclick-0.1.2-py3-none-any.whl
# Installing collected packages: markovclick
# Successfully installed markovclick-0.1.2

# %% [markdown]
# # New Section

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Likhit.csv")

# %%
df.head()
# Out:
#    USERS    1    2    3    4    5    6  ...   23   24   25   26   27   28   29
# 0  user1   A1   A2   A1   A1   A3   A4  ...   A9   A2   A7   A1   A1  A10   A1
# 1  user2   A1   A2   A7  NaN  A20  A11  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  user3   A1  NaN  A23  NaN   A1  A16  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  User4   A1   A1   A1   A1   A1   A1  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  User5  A12   A1   A1   A1   A5   A5  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 30 columns]

# %%
df.set_index(df.columns[0],inplace=True)

# %%
df.head()
# Out:
#          1    2    3    4    5    6    7  ...   23   24   25   26   27   28   29
# USERS                                     ...
# user1   A1   A2   A1   A1   A3   A4   A1  ...   A9   A2   A7   A1   A1  A10   A1
# user2   A1   A2   A7  NaN  A20  A11  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# user3   A1  NaN  A23  NaN   A1  A16  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# User4   A1   A1   A1   A1   A1   A1   A9  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# User5  A12   A1   A1   A1   A5   A5   A5  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 29 columns]

# %%
data=[]
for i in range(100):
    x=df.values[i]
    x=x[~pd.isnull(x)]
    data.append(x)
data
# Out:
# [array(['A1', 'A2', 'A1', 'A1', 'A3', 'A4', 'A1', 'A1', 'A5', 'A6', 'A5',
#         'A1', 'A6', 'A1', 'A7', 'A2', 'A2', 'A8', 'A8', 'A2', 'A2', 'A9',
#         'A2', 'A7', 'A1', 'A1', 'A10', 'A1'], dtype=object),
#  array(['A1', 'A2', 'A7', 'A20', 'A11'], dtype=object),
#  array(['A1', 'A23', 'A1', 'A16'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A9', 'A1', 'A1', 'A9', 'A10',
#         'A9', 'A11', 'A11', 'A8', 'A1'], dtype=object),
#  array(['A12', 'A1', 'A1', 'A1', 'A5', 'A5', 'A5', 'A13', 'A13', 'A1',
#         'A14', 'A1'], dtype=object),
#  array(['A1', 'A12', 'A12', 'A12', 'A12', 'A12', 'A15', 'A16', 'A16',
#         'A17', 'A18', 'A19', 'A6', 'A1'], dtype=object),
#  array(['A12', 'A2', 'A1', 'A4', 'A1', 'A4', 'A1', 'A4', 'A14', 'A4', 'A1',
#         'A4', 'A20', 'A5', 'A4', 'A1'], dtype=object),
#  array(['A1', 'A6', 'A1', 'A15', 'A1', 'A1', 'A1', 'A1', 'A15', 'A21',
#         'A1', 'A21', 'A9', 'A9', 'A1', 'A9', 'A1'], dtype=object),
#  array(['A5', 'A4', 'A1', 'A5', 'A4', 'A4', 'A1', 'A1', 'A1', 'A1', 'A9',
#         'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A21', 'A4', 'A9', 'A1', 'A1', 'A1', 'A10', 'A10', 'A9',
#         'A11', 'A11', 'A9', 'A14', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A13', 'A1', 'A8', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A15', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A6', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A15'], dtype=object),
#  array(['A1', 'A17', 'A8', 'A4', 'A3'], dtype=object),
#  array(['A1', 'A8', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A9'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A14'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A20'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A14', 'A13'], dtype=object),
#  array(['A1', 'A5', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A12', 'A15'], dtype=object),
#  array(['A1', 'A21', 'A13', 'A1', 'A15'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A15', 'A2', 'A15', 'A14'], dtype=object),
#  array(['A1', 'A3', 'A1'], dtype=object),
#  array(['A1', 'A13', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A4', 'A7', 'A5', 'A20', 'A7', 'A9'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A23', 'A6'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A7', 'A7'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A15', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A13', 'A1'], dtype=object),
#  array(['A1', 'A5', 'A19', 'A19'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1', 'A14'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A8', 'A3', 'A8', 'A8'], dtype=object),
#  array(['A1', 'A1', 'A6', 'A6'], dtype=object),
#  array(['A1', 'A16', 'A1', 'A26', 'A20'], dtype=object),
#  array(['A1', 'A20', 'A1', 'A20'], dtype=object),
#  array(['A1', 'A27', 'A3', 'A27', 'A8'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A2', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A7', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A4', 'A9', 'A10', 'A9', 'A27', 'A27', 'A4', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A6', 'A2', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A15'], dtype=object),
#  array(['A1', 'A10', 'A10'], dtype=object),
#  array(['A1', 'A14', 'A13', 'A13', 'A17', 'A19', 'A20', 'A19', 'A1', 'A1'],
#        dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A28', 'A28'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A13', 'A32', 'A32', 'A13', 'A1', 'A30', 'A22', 'A15', 'A1', 'A29',
#         'A20', 'A20', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A8', 'A1'], dtype=object),
#  array(['A20', 'A4', 'A1'], dtype=object),
#  array(['A37', 'A4', 'A1', 'A4', 'A1', 'A6', 'A2', 'A1'], dtype=object),
#  array(['A22', 'A30', 'A30', 'A5', 'A22', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A13', 'A1', 'A15', 'A1', 'A5', 'A1', 'A1', 'A1'],
#        dtype=object),
#  array(['A1', 'A16', 'A1', 'A26'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A15', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A13', 'A13'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A5', 'A1'], dtype=object),
#  array(['A1', 'A7', 'A7'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A9', 'A1', 'A1', 'A1', 'A8', 'A1', 'A15',
#         'A1', 'A1', 'A1'], dtype=object)]

# %%
from markovclick.models import MarkovClickstream
m = MarkovClickstream(data)

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
sns.heatmap(m.prob_matrix, xticklabels=m.pages, yticklabels=m.pages,cmap="YlGnBu")

# %%
from markovclick.viz import visualise_markov_chain
graph = visualise_markov_chain(m)

# %%
print(graph.source)
# Out:
# digraph {
# 	A1 [label=A1 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A1 -> A1 [label=0.46 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A1 -> A15 [label="   0.07" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A10 [label=A10 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A10 -> A9 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A10 -> A10 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A11 [label=A11 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A11 -> A11 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A11 -> A9 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A12 [label=A12 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A12 -> A12 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A12 -> A15 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A13 [label=A13 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A13 -> A1 [label=0.58 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A13 -> A13 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A14 [label=A14 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A14 -> A1 [label=0.40 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A14 -> A13 [label="   0.40" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A14 -> A14 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A15 [label=A15 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A15 -> A1 [label=0.64 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A15 -> A14 [label="   0.09" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A15 -> A15 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A16 [label=A16 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A16 -> A1 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A16 -> A16 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A17 [label=A17 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A17 -> A8 [label=0.33 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A17 -> A18 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A17 -> A17 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A18 [label=A18 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A18 -> A19 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A18 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A18 -> A18 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A19 [label=A19 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A19 -> A1 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A19 -> A6 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A19 -> A19 [label="   0.25" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A2 [label=A2 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A2 -> A1 [label=0.38 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A2 -> A7 [label="   0.15" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A2 -> A2 [label="   0.15" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A20 [label=A20 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A20 -> A1 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A20 -> A20 [label="   0.12" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A21 [label=A21 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A21 -> A9 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A21 -> A4 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A21 -> A21 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A22 [label=A22 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A22 -> A1 [label=0.33 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A22 -> A15 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A22 -> A22 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A23 [label=A23 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A23 -> A1 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A23 -> A6 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A23 -> A23 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A26 [label=A26 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A26 -> A20 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A26 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A26 -> A26 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A27 [label=A27 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A27 -> A3 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A27 -> A8 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A27 -> A27 [label="   0.25" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A28 [label=A28 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A28 -> A28 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A28 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A29 [label=A29 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A29 -> A20 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A29 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A29 -> A29 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A3 [label=A3 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A3 -> A1 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A3 -> A4 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A3 -> A3 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A30 [label=A30 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A30 -> A22 [label=0.33 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A30 -> A5 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A30 -> A30 [label="   0.33" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A32 [label=A32 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A32 -> A13 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A32 -> A32 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A37 [label=A37 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A37 -> A4 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A37 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A37 -> A37 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A4 [label=A4 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A4 -> A1 [label=0.61 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A4 -> A9 [label="   0.11" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A4 -> A4 [label="   0.06" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A5 [label=A5 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A5 -> A1 [label=0.29 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A5 -> A4 [label="   0.21" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A5 -> A5 [label="   0.14" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A6 [label=A6 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A6 -> A1 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A6 -> A2 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A6 -> A6 [label="   0.12" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A7 [label=A7 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A7 -> A1 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A7 -> A7 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A8 [label=A8 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A8 -> A1 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A8 -> A8 [label="   0.20" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A9 [label=A9 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A9 -> A1 [label=0.43 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A9 -> A10 [label="   0.14" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A9 -> A9 [label="   0.07" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# }

# %%
graph.render('test-output/round-table.gv', view=True)
# Out:
# 'test-output/round-table.gv.pdf'

# %%
graph
